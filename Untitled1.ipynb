# %%
# !python demo.py
# Out:
# ...
# 🎯 BEARING FAULT PREDICTION - LIVE DEMO
# ...
#
# 📊 Starting live demo...
# Simulating real-time bearing monitoring over 336 hours...
#
# /Users/vrushalidhakane/bearing-fault-project/demo.py:97: UserWarning: Glyph 128308 (\N{LARGE RED CIRCLE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /Users/vrushalidhakane/bearing-fault-project/demo.py:97: UserWarning: Glyph 128994 (\N{LARGE GREEN CIRCLE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# Figure(1400x1000)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# ⏱️    35.9h | Sample  50/460 | Stage: Normal       | Score: 0.7500
# Figure(640x480)
# Figure(640x480)
# ...
